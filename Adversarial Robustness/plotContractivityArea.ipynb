# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
#matplotlib.rcParams['font.size']=45
#matplotlib.rcParams['font.family'] = 'serif'
matplotlib.rcParams['font.family']= 'ptm' #'Times New Roman'
# Out:
# /var/folders/t4/p3rsq6254flg_bnmk_p_xgkw0000gn/T/ipykernel_73468/2246194590.py:2: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

# %%
a = 0.5
S = 1
l1 = lambda x: np.sqrt(1-2*a*x+x**2)
l2 = lambda x: 1+x

# %%
func = lambda x,y,S : (l1(x/S)**S) * (l2(y/S)**S)

# %%
d = np.linspace(0,1,2000)
x,y = np.meshgrid(d,d)

fig = plt.figure(dpi=600)

im = plt.imshow( ((func(x,y,1)<=1)).astype(int) , 
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greens")


plt.xlabel("$h_1$",fontsize=30)
plt.ylabel("$h_2$",fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("contractivityRegion.pdf",bbox_inches='tight')

plt.show()

# %%
d = np.linspace(0,1,2000)
x,y = np.meshgrid(d,d)

fig = plt.figure(dpi=600)

im = plt.imshow( ((func(x,y,2)<=1)).astype(int) , 
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greens")


plt.xlabel("$h_1$",fontsize=30)
plt.ylabel("$h_2$",fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("widerArea.pdf",bbox_inches='tight')

plt.show()

# %%
a = 0.5
S = 2
l1 = lambda x: 1-a*x+x**2/4
l2 = lambda x: 1+x

func = lambda x,y : l1(x) * l2(y)
func(0.11,0.0548)
# Out:
# 0.9999767699999998

# %%
fig = plt.figure(dpi=600)

a = 0.5
S = 2
l1 = lambda x: 1-a*x+x**2/4
l2 = lambda x: 1+x

func = lambda x,y : l1(x) * l2(y)

rect = lambda x,y : y

d = np.linspace(0,2,2000)
x,y = np.meshgrid(d,d)

from matplotlib.patches import Rectangle


fig = plt.figure(dpi=600)

plt.imshow( ((func(x,y)<=1)).astype(int) ,
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greens",label="Contractive area")

plt.gca().add_patch(
     Rectangle(
        (0.11, 0),
        1.78,
        0.05,
        fill=True,
        color="red"# remove background
     ) )

plt.ylim(0,1)

#plt.plot(d,d/4,'r-',linewidth=2,label=r"Line $h_2 = h_1/4$")
#plt.legend()
#pp = np.array([1,0.3])
#plt.plot(pp[0],pp[1],'ro')

plt.xlabel("$h_1$",fontsize=20)
plt.ylabel("$h_2$",fontsize=20)
plt.savefig("internal_rectangle.pdf",bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(dpi=600)

a = 0.5
S = 2
l1 = lambda x: 1-a*x+x**2/4
l2 = lambda x: 1+x

func = lambda x,y : l1(x) * l2(y)

rect = lambda x,y : y

d = np.linspace(0,2,2000)
x,y = np.meshgrid(d,d)

from matplotlib.patches import Rectangle


fig = plt.figure(dpi=600)

plt.imshow( ((func(x,y)<=1)).astype(int) ,
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greens",label="Contractive area")

'''plt.gca().add_patch(
     Rectangle(
        (0.11, 0),
        1.78,
        0.05,
        fill=True,
        color="red"# remove background
     ) )'''

plt.ylim(0,1)

#plt.plot(d,d/4,'r-',linewidth=2,label=r"Line $h_2 = h_1/4$")
#plt.legend()
#pp = np.array([1,0.3])
#plt.plot(pp[0],pp[1],'ro')

plt.xlabel("$h_1$",fontsize=20)
plt.ylabel("$h_2$",fontsize=20)
plt.savefig("half_step_area.pdf",bbox_inches='tight')
plt.show()
