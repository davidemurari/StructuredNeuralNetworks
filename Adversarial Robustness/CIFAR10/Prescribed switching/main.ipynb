# %%
pip install foolbox
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: foolbox in /usr/local/lib/python3.7/dist-packages (3.3.3)
# Requirement already satisfied: eagerpy>=0.30.0 in /usr/local/lib/python3.7/dist-packages (from foolbox) (0.30.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from foolbox) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from foolbox) (1.7.3)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.7/dist-packages (from foolbox) (2.28.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from foolbox) (57.4.0)
# Requirement already satisfied: GitPython>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from foolbox) (3.1.27)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.7/dist-packages (from foolbox) (4.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=3.0.7->foolbox) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=3.0.7->foolbox) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (2.10)

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import random
import foolbox as fb
import torch.optim as optim


trainMode = True
constrain = True
randd = random.randint(0,1000)
#randd = 528
print(f"Current random number : {randd}")
from google.colab import drive
drive.mount('/content/gdrive')
# %cd "/content/gdrive/My Drive/NewExperimentRobustness"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
from utils import *
from NormalizedConvolutions import *
from networkTraining import *
from multiClassHinge import *
from LipschitzConstant import *
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
# Out:
# Current random number : 266
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/NewExperimentRobustness
# cuda:0

# %%
# Normalize the test set same as training set without augmentation
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
batch_size = 128

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
a = 0.5
M = 1
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Normalisation(torch.nn.Module):
    def __init__(self, means=(0.4914, 0.4822, 0.4465), stds=(0.247, 0.243, 0.261)):
        super().__init__()
        assert len(means) == len(stds)
        self.means = means
        self.stds = stds
    
    def forward(self, x):
        return (x - torch.tensor(self.means, device=x.device).view(1, len(self.means), 1, 1)) / torch.tensor(self.stds, device=x.device).view(1, len(self.means), 1, 1)

transform_test_rob = transforms.Compose([
    transforms.ToTensor()
])
batch_size = 1024
testset_rob = torchvision.datasets.CIFAR10(root='./data', train=False,
                                      download=True, transform=transform_test_rob)
testloader_rob = torch.utils.data.DataLoader(testset_rob, batch_size=batch_size,
                                        shuffle=False, num_workers=2)
images, labels = next(iter(testloader_rob))
images, labels = images.to(device), labels.to(device)
# Out:
# Files already downloaded and verified

# %%
#marginList = [0.05, 0.07, 0.1, 0.15,0.3, 0.5]
marginList = [0.07, 0.15,0.3]
#marginList = [0.15]
#marginList = [0.07]
epsilons = [0.0, 8/255, 16/255, 36/255, 0.3, 0.5, 0.6, 0.8, 1.0]
saveRobAcc = np.zeros((len(marginList),len(epsilons)))
it = 0
for num,margin in enumerate(marginList):

  print(f"\n\n Now we are working with margin = {margin}\n\n")

  net = Network(3,32,64,128,4,4,4,S = 2, a = a, M=M)
  net.to(device);

  criterion = multiClassHingeLoss(margin = margin)
  #criterion = torch.nn.MultiMarginLoss(p=1, margin=margin)
  lr = 0.01
  
  optimizer = optim.SGD(net.parameters(),lr=lr,momentum=0.9)#,weight_decay=1e-4)
  #optimizer = optim.Adam(net.parameters(),lr=lr)#,weight_decay=1e-4)
  scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
  
  model_save_name = f'CertifiedLip_margin_{margin}.pt'
  path = F"{model_save_name}" 

  if trainMode:
    loss = -1
    while loss<0:
      print(f"Training with learning rate {lr}")
      loss = train(net, margin, criterion, optimizer, scheduler, trainloader, testloader, device, epochs=100, reg=True, a=a, constrain = constrain)
      if loss<0:
        net = Network(3,32,64,128,4,4,4,S=2,a=a,M=M)
        net.to(device);
        lr/=10
        optimizer = optim.SGD(net.parameters(),lr=lr,momentum=0.9)#,weight_decay=1e-4)
        #optimizer = optim.Adam(net.parameters(),lr=lr)#,weight_decay=1e-4)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)


    torch.save(net.state_dict(), path)
  else:
    net.load_state_dict(torch.load(path))
  
  model = nn.Sequential(Normalisation(),net).eval()
  fmodel = fb.PyTorchModel(model, bounds=(0, 1))

  acc = fb.utils.accuracy(fmodel, images, labels)

  attack = fb.attacks.L2PGD(steps=10)
  _, advs, success = attack(fmodel, images, labels, epsilons=epsilons)
  robust_accuracy = torch.mean((1-1.*success),axis=1)
  saveRobAcc[num] = robust_accuracy.detach().cpu().numpy()

  it += 1
  destination = f"updateMargin_{margin}.txt"
  np.savetxt(destination, saveRobAcc.reshape(-1,1))

  fig = plt.figure(figsize=(20,10))
  plt.plot(epsilons,robust_accuracy.detach().cpu().numpy(),'r-*',label="Experimental")
  plt.xlabel(r"$\varepsilon$",fontsize=20)
  plt.ylabel("Robust accuracy",fontsize=20)
  plt.xticks(fontsize=20)
  plt.yticks(fontsize=20)
  plt.legend(fontsize=20,loc=1)
  plt.title(f"L2 robustness. Trained with margin = {margin}. Test accuracy = {round(acc * 100,2)}%",fontsize=20);

  plt.savefig(f'L2margin_{margin}.png')
  
fig = plt.figure(figsize=(20,10))

for i in range(len(marginList)):
  plt.plot(epsilons,saveRobAcc[i],'-*',label=f"Margin = {marginList[i]}")

plt.xlabel(r"$\varepsilon$",fontsize=20)
plt.ylabel("Robust accuracy",fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20,loc=1)
plt.title(f"L2 robustness comparison CIFAR10",fontsize=20);

plt.savefig(f'L2RobustnessComparison.png')
# Out:
#  Now we are working with margin = 0.07
#
#
# Training with learning rate 0.01
# Initial regularization :  tensor(59.9294, device='cuda:0', grad_fn=<AddBackward0>)
#
#
# epoch 0, rescalings_0 :  tensor([0.2772, 0.0395, 0.7851], device='cuda:0')
# epoch 0, rescalings_1 :  tensor([0.3952, 0.2507, 0.4985], device='cuda:0')
# epoch 0, rescalings_2 :  tensor([0.5769, 0.2606, 0.4791], device='cuda:0')
# Loss [1, 100](epoch, minibatch):  3.918766392469406
# Loss [1, 200](epoch, minibatch):  0.7883497899770737
# Loss [1, 300](epoch, minibatch):  0.6275416696071625
# epoch 0, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 0, dts_1 :  tensor([0.1412, 0.3000, 0.2318, 0.5393], device='cuda:0')
# epoch 0, dts_2 :  tensor([0.2602, 0.6368, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0001798868179321, 0.9984593987464905, 0.9997225403785706, 1.000065803527832, 1.0003139972686768, 1.0015034675598145, 1.0030765533447266, 0.997016966342926, 1.0003083944320679, 0.996720016002655, 1.000433087348938, 1.0004764795303345]
# Orthogonality violation: [0.0002553826489020139, 0.003970469813793898, 0.005050585139542818, 0.002476594178006053, 0.002258873777464032, 0.002722320146858692, 0.004496059380471706, 0.006561447400599718, 0.0012199602788314223, 0.00957919005304575, 0.002689292887225747, 0.0044897329062223434]
# Reg term: 0.04576990753412247
# Norms lifting layers: [0.974193811416626, 0.977787971496582, 0.9767223596572876]
# Lifting orth viol: [1.6727067232131958, 5.628881931304932, 7.95537805557251]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 22 %
# epoch 1, rescalings_0 :  tensor([0.2946, 0.0398, 1.1189], device='cuda:0')
# epoch 1, rescalings_1 :  tensor([0.4011, 0.2722, 0.9480], device='cuda:0')
# epoch 1, rescalings_2 :  tensor([0.5987, 0.2586, 0.9472], device='cuda:0')
# Loss [2, 100](epoch, minibatch):  0.4391773700714111
# Loss [2, 200](epoch, minibatch):  0.427714558839798
# Loss [2, 300](epoch, minibatch):  0.4149751725792885
# epoch 1, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 1, dts_1 :  tensor([0.1412, 0.3000, 0.1783, 0.3900], device='cuda:0')
# epoch 1, dts_2 :  tensor([0.2173, 0.4957, 0.1416, 0.3010], device='cuda:0')
# Norms: [1.0007998943328857, 1.0026594400405884, 0.9983406662940979, 1.0030956268310547, 1.0000622272491455, 1.0029305219650269, 1.0000724792480469, 1.0048542022705078, 0.9998966455459595, 0.9955015778541565, 1.000349998474121, 0.9943429231643677]
# Orthogonality violation: [0.0018059678841382265, 0.006555521860718727, 0.0034715684596449137, 0.00612704548984766, 0.001957477768883109, 0.004309840966016054, 0.0025349047500640154, 0.004647606518119574, 0.004173077642917633, 0.010880397632718086, 0.002153936307877302, 0.009192388504743576]
# Reg term: 0.0578097328543663
# Norms lifting layers: [0.9982403516769409, 0.99409019947052, 0.9933332204818726]
# Lifting orth viol: [1.550969123840332, 5.635495185852051, 7.983866214752197]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 27 %
# epoch 2, rescalings_0 :  tensor([0.3045, 0.0395, 1.3221], device='cuda:0')
# epoch 2, rescalings_1 :  tensor([0.4063, 0.2878, 1.1940], device='cuda:0')
# epoch 2, rescalings_2 :  tensor([0.6303, 0.2591, 1.2083], device='cuda:0')
# Loss [3, 100](epoch, minibatch):  0.3896555957198143
# Loss [3, 200](epoch, minibatch):  0.3528939867019653
# Loss [3, 300](epoch, minibatch):  0.3390726879239082
# epoch 2, dts_0 :  tensor([0.1412, 0.3002, 0.1412, 0.3001], device='cuda:0')
# epoch 2, dts_1 :  tensor([0.1414, 0.3005, 0.1413, 0.3004], device='cuda:0')
# epoch 2, dts_2 :  tensor([0.1698, 0.3687, 0.1416, 0.3011], device='cuda:0')
# Norms: [0.999780535697937, 1.0078024864196777, 1.0004076957702637, 1.0048108100891113, 1.0011292695999146, 1.001267433166504, 0.9938815832138062, 1.001312494277954, 1.0005853176116943, 1.0381944179534912, 0.9997581243515015, 1.0057368278503418]
# Orthogonality violation: [0.001649149926379323, 0.009212655015289783, 0.0005664662458002567, 0.007423711009323597, 0.0022071271669119596, 0.0028347913175821304, 0.008913271129131317, 0.003848268883302808, 0.008946684189140797, 0.023914312943816185, 0.0019270923221483827, 0.007715373300015926]
# Reg term: 0.07915890216827393
# Norms lifting layers: [0.999931812286377, 0.997446596622467, 0.9990721940994263]
# Lifting orth viol: [1.524872064590454, 5.608529090881348, 7.968915939331055]
# Norm last linear: 1.0
# Current accuracy on test points: 33 %
# epoch 3, rescalings_0 :  tensor([0.3061, 0.0361, 1.5236], device='cuda:0')
# epoch 3, rescalings_1 :  tensor([0.4071, 0.2900, 1.4254], device='cuda:0')
# epoch 3, rescalings_2 :  tensor([0.6568, 0.2626, 1.4607], device='cuda:0')
# Loss [4, 100](epoch, minibatch):  0.31154267728328705
# Loss [4, 200](epoch, minibatch):  0.29182197600603105
# Loss [4, 300](epoch, minibatch):  0.2772476631402969
# epoch 3, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 3, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 3, dts_2 :  tensor([0.1449, 0.3087, 0.1414, 0.3005], device='cuda:0')
# Norms: [0.9994922280311584, 0.9980525970458984, 1.0007755756378174, 0.9996240139007568, 1.0038844347000122, 1.0008978843688965, 0.9971133470535278, 1.0030335187911987, 0.9999887943267822, 0.9950575232505798, 0.9997878074645996, 0.9981503486633301]
# Orthogonality violation: [0.002246155636385083, 0.013225069269537926, 0.0008868806762620807, 0.010761618614196777, 0.0036360910162329674, 0.009009870700538158, 0.009296789765357971, 0.009560682810842991, 0.0038601811975240707, 0.014386412687599659, 0.002237919718027115, 0.012892911210656166]
# Reg term: 0.0920005813241005
# Norms lifting layers: [0.9905975461006165, 0.9774057269096375, 0.9935018420219421]
# Lifting orth viol: [1.5165637731552124, 5.568619728088379, 7.939122200012207]
# Norm last linear: 1.0
# Current accuracy on test points: 39 %
# epoch 4, rescalings_0 :  tensor([0.2969, 0.0266, 1.7112], device='cuda:0')
# epoch 4, rescalings_1 :  tensor([0.4071, 0.2917, 1.6334], device='cuda:0')
# epoch 4, rescalings_2 :  tensor([0.6742, 0.2682, 1.6890], device='cuda:0')
# Loss [5, 100](epoch, minibatch):  0.2708615861833096
# Loss [5, 200](epoch, minibatch):  0.25216140210628507
# Loss [5, 300](epoch, minibatch):  0.2567534288764
# epoch 4, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 4, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 4, dts_2 :  tensor([0.1421, 0.3022, 0.1415, 0.3009], device='cuda:0')
# Norms: [1.001166820526123, 1.0151238441467285, 0.9952971339225769, 1.0128382444381714, 1.0009428262710571, 1.0127700567245483, 1.002995491027832, 1.0141711235046387, 1.0003119707107544, 1.0106749534606934, 1.0002267360687256, 1.0127707719802856]
# Orthogonality violation: [0.001980558969080448, 0.018962113186717033, 0.0036217421293258667, 0.01665395125746727, 0.0051942975260317326, 0.014247088693082333, 0.005114211700856686, 0.015117470175027847, 0.0016700737178325653, 0.01913149654865265, 0.002049966948106885, 0.01943662017583847]
# Reg term: 0.12317958474159241
# Norms lifting layers: [0.9986735582351685, 0.9919862747192383, 0.9923582077026367]
# Lifting orth viol: [1.486964464187622, 5.564888000488281, 7.902834415435791]
# Norm last linear: 1.0
# Current accuracy on test points: 48 %
# epoch 5, rescalings_0 :  tensor([0.2880, 0.0140, 1.8761], device='cuda:0')
# epoch 5, rescalings_1 :  tensor([0.4080, 0.2934, 1.8221], device='cuda:0')
# epoch 5, rescalings_2 :  tensor([0.6868, 0.2734, 1.9026], device='cuda:0')
# Loss [6, 100](epoch, minibatch):  0.24396134793758392
# Loss [6, 200](epoch, minibatch):  0.24135129004716874
# Loss [6, 300](epoch, minibatch):  0.2428005249798298
# epoch 5, dts_0 :  tensor([0.1412, 0.3002, 0.1413, 0.3003], device='cuda:0')
# epoch 5, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3001], device='cuda:0')
# epoch 5, dts_2 :  tensor([0.1425, 0.3032, 0.1418, 0.3016], device='cuda:0')
# Norms: [1.001129150390625, 0.9983504414558411, 0.9956601858139038, 1.0008546113967896, 1.0021910667419434, 1.0035369396209717, 0.997679591178894, 1.0026090145111084, 1.0003623962402344, 1.0187888145446777, 1.0001739263534546, 1.012026309967041]
# Orthogonality violation: [0.0020992548670619726, 0.013613342307507992, 0.003915257286280394, 0.012004295364022255, 0.0025444503407925367, 0.013047302141785622, 0.003861659672111273, 0.013005353510379791, 0.002165843266993761, 0.01825058087706566, 0.002195780398324132, 0.016769926995038986]
# Reg term: 0.10347304493188858
# Norms lifting layers: [0.9993233680725098, 0.999869704246521, 1.0015767812728882]
# Lifting orth viol: [1.481015920639038, 5.538142204284668, 7.870691299438477]
# Norm last linear: 1.0
# Current accuracy on test points: 52 %
# epoch 6, rescalings_0 :  tensor([2.7625e-01, 1.9258e-03, 2.0084e+00], device='cuda:0')
# epoch 6, rescalings_1 :  tensor([0.4098, 0.2942, 1.9824], device='cuda:0')
# epoch 6, rescalings_2 :  tensor([0.6981, 0.2775, 2.1011], device='cuda:0')
# Loss [7, 100](epoch, minibatch):  0.2291836655139923
# Loss [7, 200](epoch, minibatch):  0.2215547177195549
# Loss [7, 300](epoch, minibatch):  0.216849162876606
# epoch 6, dts_0 :  tensor([0.1412, 0.3000, 0.1413, 0.3003], device='cuda:0')
# epoch 6, dts_1 :  tensor([0.1412, 0.3000, 0.1413, 0.3004], device='cuda:0')
# epoch 6, dts_2 :  tensor([0.1421, 0.3023, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9994620680809021, 1.0036057233810425, 1.0003001689910889, 1.00312077999115, 0.9985004663467407, 1.0083701610565186, 0.9983137845993042, 1.0080682039260864, 0.9999655485153198, 1.0128488540649414, 1.0000067949295044, 1.0048431158065796]
# Orthogonality violation: [0.0019410870736464858, 0.009435134939849377, 0.001440416555851698, 0.00900941714644432, 0.0037405584007501602, 0.010259305126965046, 0.007903320714831352, 0.010323623195290565, 0.0025052065029740334, 0.017918504774570465, 0.0021242196671664715, 0.013069380074739456]
# Reg term: 0.08967017382383347
# Norms lifting layers: [0.9928005337715149, 0.9896401762962341, 0.9956068992614746]
# Lifting orth viol: [1.4890705347061157, 5.508640289306641, 7.842597961425781]
# Norm last linear: 1.0
# Current accuracy on test points: 53 %
# epoch 7, rescalings_0 :  tensor([0.2656, 0.0000, 2.1495], device='cuda:0')
# epoch 7, rescalings_1 :  tensor([0.4083, 0.2938, 2.1536], device='cuda:0')
# epoch 7, rescalings_2 :  tensor([0.7095, 0.2802, 2.3154], device='cuda:0')
# Loss [8, 100](epoch, minibatch):  0.21533416628837584
# Loss [8, 200](epoch, minibatch):  0.2024151337146759
# Loss [8, 300](epoch, minibatch):  0.1931120578944683
# epoch 7, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 7, dts_1 :  tensor([0.1412, 0.3000, 0.1417, 0.3013], device='cuda:0')
# epoch 7, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9998929500579834, 0.9990652799606323, 0.9989860653877258, 0.999308705329895, 0.9969204068183899, 1.0030583143234253, 0.9967265129089355, 1.0020995140075684, 0.9999850392341614, 1.0190355777740479, 1.0000234842300415, 1.0056309700012207]
# Orthogonality violation: [0.001782227074727416, 0.015170424245297909, 0.0033286460675299168, 0.014091975055634975, 0.004835250787436962, 0.013974914327263832, 0.00872158631682396, 0.014042550697922707, 0.0015437334077432752, 0.027925796806812286, 0.002251619240269065, 0.018305793404579163]
# Reg term: 0.12597450613975525
# Norms lifting layers: [0.9967381358146667, 0.9998136758804321, 0.998222827911377]
# Lifting orth viol: [1.487641453742981, 5.474361419677734, 7.8251729011535645]
# Norm last linear: 1.0000001192092896
# Current accuracy on test points: 59 %
# epoch 8, rescalings_0 :  tensor([0.2526, 0.0000, 2.2967], device='cuda:0')
# epoch 8, rescalings_1 :  tensor([0.4046, 0.2941, 2.3369], device='cuda:0')
# epoch 8, rescalings_2 :  tensor([0.7196, 0.2830, 2.5460], device='cuda:0')
# Loss [9, 100](epoch, minibatch):  0.18978731021285056
# Loss [9, 200](epoch, minibatch):  0.20074944004416465
# Loss [9, 300](epoch, minibatch):  0.18131498441100122
# epoch 8, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 8, dts_1 :  tensor([0.1412, 0.3001, 0.1417, 0.3012], device='cuda:0')
# epoch 8, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0004031658172607, 1.0063295364379883, 1.0000087022781372, 1.006134033203125, 0.9999176263809204, 1.0101993083953857, 0.9989835023880005, 1.0093834400177002, 1.0003637075424194, 1.0137759447097778, 1.0000905990600586, 1.0030306577682495]
# Orthogonality violation: [0.0020478349179029465, 0.011701780371367931, 0.0003544700157362968, 0.011375293135643005, 0.0027445582672953606, 0.012249941937625408, 0.005648519843816757, 0.01206845510751009, 0.0017330700065940619, 0.019880829378962517, 0.0019210615428164601, 0.012301240116357803]
# Reg term: 0.09402705729007721
# Norms lifting layers: [0.989823579788208, 0.990709125995636, 0.9985637664794922]
# Lifting orth viol: [1.4861762523651123, 5.454076766967773, 7.830642223358154]
# Norm last linear: 1.0
# Current accuracy on test points: 61 %
# epoch 9, rescalings_0 :  tensor([0.2402, 0.0000, 2.4291], device='cuda:0')
# epoch 9, rescalings_1 :  tensor([0.3990, 0.2946, 2.5075], device='cuda:0')
# epoch 9, rescalings_2 :  tensor([0.7322, 0.2861, 2.7657], device='cuda:0')
# Loss [10, 100](epoch, minibatch):  0.18196437180042266
# Loss [10, 200](epoch, minibatch):  0.17710071966052054
# Loss [10, 300](epoch, minibatch):  0.17714251026511194
# epoch 9, dts_0 :  tensor([0.1412, 0.3002, 0.1414, 0.3005], device='cuda:0')
# epoch 9, dts_1 :  tensor([0.1412, 0.3000, 0.1414, 0.3005], device='cuda:0')
# epoch 9, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.000664234161377, 1.0164523124694824, 1.0001076459884644, 1.0170621871948242, 0.9999992251396179, 1.0086538791656494, 1.0010310411453247, 1.0081148147583008, 1.0005983114242554, 1.0013108253479004, 1.0000602006912231, 0.9928406476974487]
# Orthogonality violation: [0.00220635742880404, 0.018848642706871033, 0.002212323946878314, 0.0184150543063879, 0.0027890403289347887, 0.014157618395984173, 0.0025982733350247145, 0.01397505309432745, 0.0028458377346396446, 0.023342639207839966, 0.0023434492759406567, 0.01639397256076336]
# Reg term: 0.12012825906276703
# Norms lifting layers: [0.9906078577041626, 0.9938620924949646, 0.9949359893798828]
# Lifting orth viol: [1.4751840829849243, 5.446508884429932, 7.8446431159973145]
# Norm last linear: 1.0
# Current accuracy on test points: 58 %
# epoch 10, rescalings_0 :  tensor([0.2268, 0.0000, 2.5467], device='cuda:0')
# epoch 10, rescalings_1 :  tensor([0.3941, 0.2948, 2.6632], device='cuda:0')
# epoch 10, rescalings_2 :  tensor([0.7425, 0.2892, 2.9697], device='cuda:0')
# Loss [11, 100](epoch, minibatch):  0.1784432552754879
# Loss [11, 200](epoch, minibatch):  0.1706015756726265
# Loss [11, 300](epoch, minibatch):  0.16834992714226246
# epoch 10, dts_0 :  tensor([0.1442, 0.3071, 0.1460, 0.3114], device='cuda:0')
# epoch 10, dts_1 :  tensor([0.1430, 0.3042, 0.1448, 0.3085], device='cuda:0')
# epoch 10, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9994094371795654, 1.0012189149856567, 1.0000030994415283, 1.001715898513794, 1.0043656826019287, 1.0205543041229248, 1.0035107135772705, 1.0206891298294067, 1.0005344152450562, 1.001842737197876, 1.0000739097595215, 0.999234676361084]
# Orthogonality violation: [0.002026460599154234, 0.013001322746276855, 0.0013418201124295592, 0.0128779923543334, 0.005047841928899288, 0.017339937388896942, 0.0077722324058413506, 0.017476636916399002, 0.0034195426851511, 0.01715250499546528, 0.0020036487840116024, 0.014471732079982758]
# Reg term: 0.11393167823553085
# Norms lifting layers: [0.9940314292907715, 0.9918069243431091, 0.996871829032898]
# Lifting orth viol: [1.4726155996322632, 5.421185493469238, 7.829470157623291]
# Norm last linear: 1.0
# Current accuracy on test points: 62 %
# epoch 11, rescalings_0 :  tensor([0.2147, 0.0000, 2.6409], device='cuda:0')
# epoch 11, rescalings_1 :  tensor([0.3919, 0.2939, 2.7993], device='cuda:0')
# epoch 11, rescalings_2 :  tensor([0.7540, 0.2918, 3.1466], device='cuda:0')
# Loss [12, 100](epoch, minibatch):  0.16600290894508363
# Loss [12, 200](epoch, minibatch):  0.17283346146345138
# Loss [12, 300](epoch, minibatch):  0.16631449244916438
# epoch 11, dts_0 :  tensor([0.1427, 0.3037, 0.1450, 0.3090], device='cuda:0')
# epoch 11, dts_1 :  tensor([0.1412, 0.3000, 0.1429, 0.3041], device='cuda:0')
# epoch 11, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.999427318572998, 1.0005966424942017, 0.999927282333374, 0.9999999403953552, 1.001574993133545, 1.0075191259384155, 1.0046768188476562, 1.0073350667953491, 1.000653624534607, 1.0055959224700928, 1.0000768899917603, 1.0002696514129639]
# Orthogonality violation: [0.0024050066713243723, 0.010570741258561611, 0.0027526337653398514, 0.010891414247453213, 0.002686032559722662, 0.012493510730564594, 0.008161606267094612, 0.012497635558247566, 0.005245451349765062, 0.014069036580622196, 0.002274763537570834, 0.01137456949800253]
# Reg term: 0.0954224020242691
# Norms lifting layers: [0.9962817430496216, 0.9981144070625305, 0.999934732913971]
# Lifting orth viol: [1.4720572233200073, 5.404872894287109, 7.840730667114258]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 62 %
# epoch 12, rescalings_0 :  tensor([2.0050e-01, 3.7368e-05, 2.7328e+00], device='cuda:0')
# epoch 12, rescalings_1 :  tensor([0.3903, 0.2942, 2.9321], device='cuda:0')
# epoch 12, rescalings_2 :  tensor([0.7657, 0.2953, 3.3161], device='cuda:0')
# Loss [13, 100](epoch, minibatch):  0.16194980308413506
# Loss [13, 200](epoch, minibatch):  0.1634093127399683
# Loss [13, 300](epoch, minibatch):  0.15979601979255675
# epoch 12, dts_0 :  tensor([0.1431, 0.3046, 0.1520, 0.3255], device='cuda:0')
# epoch 12, dts_1 :  tensor([0.1412, 0.3000, 0.1413, 0.3003], device='cuda:0')
# epoch 12, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0004277229309082, 1.0061358213424683, 0.9999107122421265, 1.0070679187774658, 0.999830424785614, 1.0009211301803589, 1.002417802810669, 1.0006579160690308, 1.0002951622009277, 1.0019611120224, 1.0000240802764893, 0.9971489906311035]
# Orthogonality violation: [0.002057428704574704, 0.011588066816329956, 0.0033584327902644873, 0.011811329983174801, 0.003570695174857974, 0.015029667876660824, 0.0046501015312969685, 0.014599751681089401, 0.0026774154976010323, 0.017422407865524292, 0.0020516752265393734, 0.012981983833014965]
# Reg term: 0.10179895162582397
# Norms lifting layers: [0.9974827766418457, 0.9982268214225769, 0.9987918138504028]
# Lifting orth viol: [1.470380425453186, 5.417664051055908, 7.823355197906494]
# Norm last linear: 1.0
# Current accuracy on test points: 65 %
# epoch 13, rescalings_0 :  tensor([0.1882, 0.0000, 2.8147], device='cuda:0')
# epoch 13, rescalings_1 :  tensor([0.3898, 0.2951, 3.0522], device='cuda:0')
# epoch 13, rescalings_2 :  tensor([0.7780, 0.2988, 3.4665], device='cuda:0')
# Loss [14, 100](epoch, minibatch):  0.16159006036818027
# Loss [14, 200](epoch, minibatch):  0.15797152236104012
# Loss [14, 300](epoch, minibatch):  0.1552245470881462
# epoch 13, dts_0 :  tensor([0.1462, 0.3118, 0.1555, 0.3338], device='cuda:0')
# epoch 13, dts_1 :  tensor([0.1412, 0.3000, 0.1418, 0.3015], device='cuda:0')
# epoch 13, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0005848407745361, 1.007468581199646, 1.000074863433838, 1.0055651664733887, 1.0008437633514404, 1.0018854141235352, 0.9984717965126038, 1.0016188621520996, 1.001033067703247, 1.011291742324829, 0.9999833106994629, 0.9980508089065552]
# Orthogonality violation: [0.002149344654753804, 0.012850165367126465, 0.0027120187878608704, 0.01419433020055294, 0.00501182209700346, 0.01587754115462303, 0.0037305979058146477, 0.014935469254851341, 0.0034804283641278744, 0.023671627044677734, 0.0021756677888333797, 0.014725450426340103]
# Reg term: 0.11551446467638016
# Norms lifting layers: [0.9911437034606934, 0.9999350309371948, 0.9947612285614014]
# Lifting orth viol: [1.4678864479064941, 5.401373863220215, 7.8411173820495605]
# Norm last linear: 1.0
# Current accuracy on test points: 63 %
# epoch 14, rescalings_0 :  tensor([0.1757, 0.0000, 2.8909], device='cuda:0')
# epoch 14, rescalings_1 :  tensor([0.3905, 0.2968, 3.1659], device='cuda:0')
# epoch 14, rescalings_2 :  tensor([0.7903, 0.3019, 3.6076], device='cuda:0')
# Loss [15, 100](epoch, minibatch):  0.1541756134480238
# Loss [15, 200](epoch, minibatch):  0.15382354252040387
# Loss [15, 300](epoch, minibatch):  0.15488492913544177
# epoch 14, dts_0 :  tensor([0.1458, 0.3108, 0.1583, 0.3407], device='cuda:0')
# epoch 14, dts_1 :  tensor([0.1420, 0.3021, 0.1431, 0.3045], device='cuda:0')
# epoch 14, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9996953010559082, 1.0246777534484863, 0.9999518990516663, 1.0296051502227783, 1.0003241300582886, 1.0080811977386475, 0.9975061416625977, 1.0102088451385498, 1.0014101266860962, 1.0107176303863525, 1.0000650882720947, 0.9937422275543213]
# Orthogonality violation: [0.0017565893940627575, 0.020437082275748253, 0.0016006295336410403, 0.02247047796845436, 0.002766840159893036, 0.021419428288936615, 0.008139466866850853, 0.020093882456421852, 0.0047482820227742195, 0.028041675686836243, 0.00205325148999691, 0.018136421218514442]
# Reg term: 0.15166401863098145
# Norms lifting layers: [0.993611216545105, 0.9960442185401917, 0.9970055818557739]
# Lifting orth viol: [1.4542988538742065, 5.400148391723633, 7.827162742614746]
# Norm last linear: 1.0
# Current accuracy on test points: 63 %
# epoch 15, rescalings_0 :  tensor([0.1628, 0.0000, 2.9682], device='cuda:0')
# epoch 15, rescalings_1 :  tensor([0.3928, 0.3001, 3.2762], device='cuda:0')
# epoch 15, rescalings_2 :  tensor([0.8017, 0.3056, 3.7363], device='cuda:0')
# Loss [16, 100](epoch, minibatch):  0.15283133313059807
# Loss [16, 200](epoch, minibatch):  0.15392786256968974
# Loss [16, 300](epoch, minibatch):  0.15146446108818054
# epoch 15, dts_0 :  tensor([0.1479, 0.3159, 0.1659, 0.3592], device='cuda:0')
# epoch 15, dts_1 :  tensor([0.1426, 0.3034, 0.1442, 0.3072], device='cuda:0')
# epoch 15, dts_2 :  tensor([0.1412, 0.3000, 0.1413, 0.3003], device='cuda:0')
# Norms: [1.0003951787948608, 1.009407639503479, 1.0000293254852295, 1.0098713636398315, 0.9995884895324707, 1.0005311965942383, 0.9980545043945312, 1.0021692514419556, 1.0004726648330688, 1.0117101669311523, 1.0000594854354858, 0.9926927089691162]
# Orthogonality violation: [0.0021308348514139652, 0.01687680184841156, 0.0010734590468928218, 0.01961490511894226, 0.0037235370837152004, 0.016759391874074936, 0.00898661557585001, 0.0159929059445858, 0.002512675477191806, 0.018593549728393555, 0.0020985493902117014, 0.011939924210309982]
# Reg term: 0.12030315399169922
# Norms lifting layers: [0.9993609189987183, 0.9993852376937866, 0.9994639754295349]
# Lifting orth viol: [1.4530504941940308, 5.413813591003418, 7.835284233093262]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 65 %
# epoch 16, rescalings_0 :  tensor([0.1502, 0.0000, 3.0403], device='cuda:0')
# epoch 16, rescalings_1 :  tensor([0.3945, 0.3001, 3.3810], device='cuda:0')
# epoch 16, rescalings_2 :  tensor([0.8130, 0.3111, 3.8619], device='cuda:0')
# Loss [17, 100](epoch, minibatch):  0.1514395797252655
# Loss [17, 200](epoch, minibatch):  0.1550866239517927
# Loss [17, 300](epoch, minibatch):  0.15219078056514262
# epoch 16, dts_0 :  tensor([0.1433, 0.3050, 0.1656, 0.3584], device='cuda:0')
# epoch 16, dts_1 :  tensor([0.1429, 0.3041, 0.1437, 0.3060], device='cuda:0')
# epoch 16, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0001933574676514, 1.0047755241394043, 1.0001232624053955, 1.0015909671783447, 0.997997522354126, 1.0079245567321777, 0.9991636872291565, 1.0052599906921387, 0.9997442960739136, 0.9984537959098816, 0.9999600648880005, 1.0000460147857666]
# Orthogonality violation: [0.0020525166764855385, 0.010596830397844315, 0.001694215345196426, 0.012240848504006863, 0.005107170902192593, 0.013188378885388374, 0.0054863933473825455, 0.01240834966301918, 0.0030925844330340624, 0.012155241332948208, 0.002122078323736787, 0.012518113479018211]
# Reg term: 0.09266272187232971
# Norms lifting layers: [0.996518075466156, 0.9977383017539978, 0.995189368724823]
# Lifting orth viol: [1.4486514329910278, 5.410100936889648, 7.849711894989014]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 67 %
# epoch 17, rescalings_0 :  tensor([1.3808e-01, 1.0825e-04, 3.1137e+00], device='cuda:0')
# epoch 17, rescalings_1 :  tensor([0.3970, 0.3017, 3.4828], device='cuda:0')
# epoch 17, rescalings_2 :  tensor([0.8241, 0.3149, 3.9800], device='cuda:0')
# Loss [18, 100](epoch, minibatch):  0.15313066199421882
# Loss [18, 200](epoch, minibatch):  0.15523933283984662
# Loss [18, 300](epoch, minibatch):  0.16115155786275864
# epoch 17, dts_0 :  tensor([0.1433, 0.3051, 0.1723, 0.3750], device='cuda:0')
# epoch 17, dts_1 :  tensor([0.1416, 0.3009, 0.1421, 0.3022], device='cuda:0')
# epoch 17, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0000685453414917, 0.999618411064148, 1.0004208087921143, 1.0031098127365112, 1.000286340713501, 0.9945366382598877, 1.00078284740448, 0.99649578332901, 1.0002968311309814, 1.00424063205719, 0.9999881982803345, 1.0006601810455322]
# Orthogonality violation: [0.002458604285493493, 0.010723897255957127, 0.0009557876619510353, 0.011198615655303001, 0.0028191618621349335, 0.013093165121972561, 0.0027120315935462713, 0.01186432782560587, 0.004973017144948244, 0.015127027407288551, 0.002253266517072916, 0.013506082817912102]
# Reg term: 0.0916849821805954
# Norms lifting layers: [0.9986917972564697, 0.9996205568313599, 0.9938113689422607]
# Lifting orth viol: [1.4665042161941528, 5.407732963562012, 7.835673809051514]
# Norm last linear: 1.0
# Current accuracy on test points: 64 %
# epoch 18, rescalings_0 :  tensor([0.1272, 0.0000, 3.1769], device='cuda:0')
# epoch 18, rescalings_1 :  tensor([0.4011, 0.3047, 3.5749], device='cuda:0')
# epoch 18, rescalings_2 :  tensor([0.8355, 0.3190, 4.0857], device='cuda:0')
# Loss [19, 100](epoch, minibatch):  0.15707182079553605
# Loss [19, 200](epoch, minibatch):  0.15426754705607892
# Loss [19, 300](epoch, minibatch):  0.1575224694609642
# epoch 18, dts_0 :  tensor([0.1442, 0.3071, 0.1749, 0.3815], device='cuda:0')
# epoch 18, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 18, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0004777908325195, 1.0152767896652222, 1.0001364946365356, 1.0000393390655518, 0.9993237257003784, 0.9926727414131165, 1.0016469955444336, 0.9923007488250732, 0.9999538064002991, 0.9997859001159668, 1.000048279762268, 0.9963796138763428]
# Orthogonality violation: [0.0018699399661272764, 0.013907278887927532, 0.0003041093295905739, 0.017848918214440346, 0.003423939924687147, 0.012652814388275146, 0.007617004681378603, 0.01226555835455656, 0.0027468050830066204, 0.011433075182139874, 0.001953112194314599, 0.011289706453680992]
# Reg term: 0.09731225669384003
# Norms lifting layers: [0.998213529586792, 0.9980466365814209, 0.9972145557403564]
# Lifting orth viol: [1.476232886314392, 5.4172468185424805, 7.826356410980225]
# Norm last linear: 1.0
# Current accuracy on test points: 67 %
# epoch 19, rescalings_0 :  tensor([1.1719e-01, 3.5573e-05, 3.2395e+00], device='cuda:0')
# epoch 19, rescalings_1 :  tensor([0.4050, 0.3078, 3.6616], device='cuda:0')
# epoch 19, rescalings_2 :  tensor([0.8462, 0.3241, 4.1821], device='cuda:0')
# Loss [20, 100](epoch, minibatch):  0.14621448956429958
# Loss [20, 200](epoch, minibatch):  0.1499984260648489
# Loss [20, 300](epoch, minibatch):  0.1506841691583395
# epoch 19, dts_0 :  tensor([0.1452, 0.3094, 0.1739, 0.3791], device='cuda:0')
# epoch 19, dts_1 :  tensor([0.1416, 0.3010, 0.1417, 0.3014], device='cuda:0')
# epoch 19, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0007836818695068, 1.0219972133636475, 0.9999316334724426, 1.0246580839157104, 1.0000044107437134, 0.9964555501937866, 1.0011682510375977, 0.9965648055076599, 0.9999819397926331, 0.9951235055923462, 1.0000576972961426, 0.9903672933578491]
# Orthogonality violation: [0.002060204977169633, 0.01766880229115486, 0.003796268254518509, 0.02065679058432579, 0.00526428921148181, 0.019161948934197426, 0.008567764423787594, 0.018952833488583565, 0.003527585882693529, 0.01825142838060856, 0.0023086853325366974, 0.014200910925865173]
# Reg term: 0.13441750407218933
# Norms lifting layers: [0.9965059757232666, 0.9976135492324829, 0.9983208179473877]
# Lifting orth viol: [1.461077332496643, 5.41460657119751, 7.8288092613220215]
# Norm last linear: 1.0
# Current accuracy on test points: 66 %
# epoch 20, rescalings_0 :  tensor([0.1079, 0.0000, 3.3045], device='cuda:0')
# epoch 20, rescalings_1 :  tensor([0.4101, 0.3106, 3.7474], device='cuda:0')
# epoch 20, rescalings_2 :  tensor([0.8578, 0.3282, 4.2765], device='cuda:0')
# Loss [21, 100](epoch, minibatch):  0.15880459398031235
# Loss [21, 200](epoch, minibatch):  0.14954113520681858
# Loss [21, 300](epoch, minibatch):  0.14780837327241897
# epoch 20, dts_0 :  tensor([0.1482, 0.3164, 0.1796, 0.3935], device='cuda:0')
# epoch 20, dts_1 :  tensor([0.1449, 0.3087, 0.1458, 0.3110], device='cuda:0')
# epoch 20, dts_2 :  tensor([0.1414, 0.3005, 0.1414, 0.3005], device='cuda:0')
# Norms: [0.9993910789489746, 0.9980593919754028, 1.0004154443740845, 1.0058526992797852, 0.999252438545227, 0.9961711168289185, 1.0007905960083008, 0.9955034255981445, 1.0004386901855469, 1.0062048435211182, 0.9999610185623169, 1.001781940460205]
# Orthogonality violation: [0.002039914717897773, 0.01556884404271841, 0.002488372614607215, 0.02307846024632454, 0.0027998893056064844, 0.017227675765752792, 0.005109723191708326, 0.0165091659873724, 0.004992849659174681, 0.016748201102018356, 0.002003347733989358, 0.015289931558072567]
# Reg term: 0.12385637313127518
# Norms lifting layers: [0.9987540245056152, 0.9999381303787231, 0.9946737289428711]
# Lifting orth viol: [1.4635142087936401, 5.411478042602539, 7.834749698638916]
# Norm last linear: 1.0
# Current accuracy on test points: 67 %
# epoch 21, rescalings_0 :  tensor([9.9753e-02, 5.0906e-05, 3.3560e+00], device='cuda:0')
# epoch 21, rescalings_1 :  tensor([0.4130, 0.3120, 3.8182], device='cuda:0')
# epoch 21, rescalings_2 :  tensor([0.8677, 0.3333, 4.3561], device='cuda:0')
# Loss [22, 100](epoch, minibatch):  0.15806115426123143
# Loss [22, 200](epoch, minibatch):  0.1536953505128622
# Loss [22, 300](epoch, minibatch):  0.14823738016188145
# epoch 21, dts_0 :  tensor([0.1488, 0.3179, 0.1820, 0.3997], device='cuda:0')
# epoch 21, dts_1 :  tensor([0.1414, 0.3007, 0.1416, 0.3011], device='cuda:0')
# epoch 21, dts_2 :  tensor([0.1412, 0.3002, 0.1412, 0.3001], device='cuda:0')
# Norms: [0.9988750219345093, 1.004930019378662, 1.0000859498977661, 1.003598690032959, 0.9999698996543884, 1.0137077569961548, 1.0001585483551025, 1.0088943243026733, 0.9993765354156494, 1.0018417835235596, 0.9999680519104004, 0.9978327751159668]
# Orthogonality violation: [0.0024830950424075127, 0.018207184970378876, 0.00040580739732831717, 0.020993441343307495, 0.003615780035033822, 0.016649067401885986, 0.0031275132205337286, 0.015058963559567928, 0.0028257351368665695, 0.013929139822721481, 0.002121209865435958, 0.01253610011190176]
# Reg term: 0.11195303499698639
# Norms lifting layers: [0.9968572854995728, 0.9986059665679932, 0.9958823919296265]
# Lifting orth viol: [1.4641450643539429, 5.410652160644531, 7.820957660675049]
# Norm last linear: 1.0
# Current accuracy on test points: 67 %
# epoch 22, rescalings_0 :  tensor([0.0918, 0.0000, 3.4044], device='cuda:0')
# epoch 22, rescalings_1 :  tensor([0.4198, 0.3150, 3.8830], device='cuda:0')
# epoch 22, rescalings_2 :  tensor([0.8770, 0.3371, 4.4304], device='cuda:0')
# Loss [23, 100](epoch, minibatch):  0.15033223979175092
# Loss [23, 200](epoch, minibatch):  0.1518873703479767
# Loss [23, 300](epoch, minibatch):  0.14900347277522086
# epoch 22, dts_0 :  tensor([0.1430, 0.3042, 0.1784, 0.3904], device='cuda:0')
# epoch 22, dts_1 :  tensor([0.1440, 0.3067, 0.1447, 0.3084], device='cuda:0')
# epoch 22, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3002], device='cuda:0')
# Norms: [1.0011262893676758, 0.9999784231185913, 1.0002100467681885, 0.9982839822769165, 0.9985281825065613, 1.0009245872497559, 1.0014013051986694, 0.9978623390197754, 1.000122308731079, 1.0029975175857544, 1.0000890493392944, 1.0033186674118042]
# Orthogonality violation: [0.001708446303382516, 0.010995911434292793, 0.003416926134377718, 0.019559884443879128, 0.00544792041182518, 0.017498327419161797, 0.007822667248547077, 0.016805438324809074, 0.0034911262337118387, 0.016183068975806236, 0.0020196798723191023, 0.018243687227368355]
# Reg term: 0.12319308519363403
# Norms lifting layers: [0.9935404062271118, 0.9996689558029175, 0.9910843372344971]
# Lifting orth viol: [1.4565211534500122, 5.395498275756836, 7.834640026092529]
# Norm last linear: 1.0
# Current accuracy on test points: 67 %
# epoch 23, rescalings_0 :  tensor([0.0859, 0.0000, 3.4547], device='cuda:0')
# epoch 23, rescalings_1 :  tensor([0.4250, 0.3172, 3.9469], device='cuda:0')
# epoch 23, rescalings_2 :  tensor([0.8864, 0.3408, 4.5017], device='cuda:0')
# Loss [24, 100](epoch, minibatch):  0.15277416363358498
# Loss [24, 200](epoch, minibatch):  0.15548840954899787
# Loss [24, 300](epoch, minibatch):  0.15158593885600566
# epoch 23, dts_0 :  tensor([0.1463, 0.3120, 0.1797, 0.3938], device='cuda:0')
# epoch 23, dts_1 :  tensor([0.1422, 0.3023, 0.1430, 0.3043], device='cuda:0')
# epoch 23, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0012943744659424, 1.006033182144165, 0.9999908804893494, 1.0094316005706787, 1.000579833984375, 1.0085572004318237, 1.0014779567718506, 1.0054357051849365, 1.0000743865966797, 0.9974657893180847, 1.0001107454299927, 0.9922078847885132]
# Orthogonality violation: [0.0019106263061985373, 0.013548885472118855, 0.0037371006328612566, 0.018182305619120598, 0.00253626168705523, 0.015624025836586952, 0.00846896506845951, 0.013851052150130272, 0.004897316452115774, 0.01576029323041439, 0.0022340293508023024, 0.012219766154885292]
# Reg term: 0.11297062784433365
# Norms lifting layers: [0.9918941855430603, 0.9985194802284241, 0.9965308904647827]
# Lifting orth viol: [1.4661829471588135, 5.413402080535889, 7.830526351928711]
# Norm last linear: 1.0
# Current accuracy on test points: 67 %
# epoch 24, rescalings_0 :  tensor([7.5007e-02, 2.1173e-04, 3.5013e+00], device='cuda:0')
# epoch 24, rescalings_1 :  tensor([0.4303, 0.3207, 4.0057], device='cuda:0')
# epoch 24, rescalings_2 :  tensor([0.8955, 0.3453, 4.5688], device='cuda:0')
# Loss [25, 100](epoch, minibatch):  0.15370057970285417
# Loss [25, 200](epoch, minibatch):  0.15362022757530214
# Loss [25, 300](epoch, minibatch):  0.14863801963627338
# epoch 24, dts_0 :  tensor([0.1548, 0.3323, 0.1862, 0.4103], device='cuda:0')
# epoch 24, dts_1 :  tensor([0.1414, 0.3006, 0.1413, 0.3004], device='cuda:0')
# epoch 24, dts_2 :  tensor([0.1417, 0.3013, 0.1415, 0.3008], device='cuda:0')
# Norms: [0.9977394342422485, 1.0097973346710205, 1.0000383853912354, 1.0193777084350586, 0.9999929666519165, 1.0111865997314453, 1.0007433891296387, 1.013510823249817, 1.0001230239868164, 0.9975974559783936, 0.9998735189437866, 0.998206615447998]
# Orthogonality violation: [0.002626807661727071, 0.017811689525842667, 0.0005871587200090289, 0.0262875035405159, 0.0038389083929359913, 0.01701728068292141, 0.00511897960677743, 0.017219293862581253, 0.002456375863403082, 0.0141842570155859, 0.002026334637776017, 0.012416647747159004]
# Reg term: 0.1215912401676178
# Norms lifting layers: [0.9994244575500488, 1.0011510848999023, 0.9934715628623962]
# Lifting orth viol: [1.4584907293319702, 5.403421878814697, 7.8347978591918945]
# Norm last linear: 1.0
# Current accuracy on test points: 65 %
# epoch 25, rescalings_0 :  tensor([0.0660, 0.0000, 3.5441], device='cuda:0')
# epoch 25, rescalings_1 :  tensor([0.4349, 0.3239, 4.0617], device='cuda:0')
# epoch 25, rescalings_2 :  tensor([0.9053, 0.3503, 4.6286], device='cuda:0')
# Loss [26, 100](epoch, minibatch):  0.15689492896199225
# Loss [26, 200](epoch, minibatch):  0.16020159639418124
# Loss [26, 300](epoch, minibatch):  0.15084166333079338
# epoch 25, dts_0 :  tensor([0.1515, 0.3245, 0.1839, 0.4044], device='cuda:0')
# epoch 25, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 25, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9965528845787048, 1.0067003965377808, 1.0000178813934326, 0.9932408332824707, 1.00031316280365, 1.0018800497055054, 0.9997064471244812, 1.0014986991882324, 1.000134825706482, 0.9921917915344238, 1.0000250339508057, 0.9926178455352783]
# Orthogonality violation: [0.002981447149068117, 0.015856139361858368, 0.0010755856055766344, 0.016758522018790245, 0.005357005167752504, 0.013641519472002983, 0.0030419861432164907, 0.01282945740967989, 0.0038693896494805813, 0.013462982140481472, 0.0022875319700688124, 0.01237036194652319]
# Reg term: 0.10353192687034607
# Norms lifting layers: [0.995800256729126, 0.9990726709365845, 0.98981773853302]
# Lifting orth viol: [1.4706143140792847, 5.423123836517334, 7.827054500579834]
# Norm last linear: 1.0
# Current accuracy on test points: 63 %
# epoch 26, rescalings_0 :  tensor([0.0557, 0.0000, 3.5853], device='cuda:0')
# epoch 26, rescalings_1 :  tensor([0.4407, 0.3285, 4.1112], device='cuda:0')
# epoch 26, rescalings_2 :  tensor([0.9142, 0.3559, 4.6852], device='cuda:0')
# Loss [27, 100](epoch, minibatch):  0.15963975377380848
# Loss [27, 200](epoch, minibatch):  0.14799143880605697
# Loss [27, 300](epoch, minibatch):  0.15120879374444485
# epoch 26, dts_0 :  tensor([0.1467, 0.3129, 0.1820, 0.3995], device='cuda:0')
# epoch 26, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 26, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0013185739517212, 1.0065581798553467, 0.9991492033004761, 1.0043985843658447, 1.0005239248275757, 1.001621127128601, 0.9989354610443115, 1.0013777017593384, 0.9993796348571777, 0.9987599849700928, 0.9999873638153076, 0.9964762926101685]
# Orthogonality violation: [0.0010672000935301185, 0.01304676290601492, 0.0034379316493868828, 0.02145979180932045, 0.0028766258619725704, 0.010259031318128109, 0.007925271987915039, 0.00997814629226923, 0.0047492170706391335, 0.00986083596944809, 0.0020173760131001472, 0.009010008536279202]
# Reg term: 0.09568819403648376
# Norms lifting layers: [0.9931484460830688, 0.9993510246276855, 0.9985525608062744]
# Lifting orth viol: [1.4695760011672974, 5.415028095245361, 7.835646629333496]
# Norm last linear: 1.0
# Current accuracy on test points: 64 %
# epoch 27, rescalings_0 :  tensor([0.0472, 0.0000, 3.6282], device='cuda:0')
# epoch 27, rescalings_1 :  tensor([0.4460, 0.3339, 4.1622], device='cuda:0')
# epoch 27, rescalings_2 :  tensor([0.9236, 0.3593, 4.7397], device='cuda:0')
# Loss [28, 100](epoch, minibatch):  0.14987101703882216
# Loss [28, 200](epoch, minibatch):  0.15161528393626214
# Loss [28, 300](epoch, minibatch):  0.15069523096084594
# epoch 27, dts_0 :  tensor([0.1477, 0.3153, 0.1881, 0.4154], device='cuda:0')
# epoch 27, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 27, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0015652179718018, 1.0265251398086548, 0.9996559023857117, 1.028656244277954, 1.0004286766052246, 1.0096826553344727, 1.000164270401001, 1.0083105564117432, 0.999573826789856, 0.9955800771713257, 0.9999963641166687, 0.9928928017616272]
# Orthogonality violation: [0.00116446812171489, 0.023565014824271202, 0.00198191124945879, 0.028789421543478966, 0.003726067952811718, 0.020670689642429352, 0.008615992963314056, 0.020682796835899353, 0.002682277699932456, 0.019212454557418823, 0.0022951511200517416, 0.014854267239570618]
# Reg term: 0.14824050664901733
# Norms lifting layers: [0.9901551008224487, 0.9945448637008667, 0.9923354387283325]
# Lifting orth viol: [1.4768176078796387, 5.4215874671936035, 7.8380327224731445]
# Norm last linear: 1.0
# Current accuracy on test points: 62 %
# epoch 28, rescalings_0 :  tensor([0.0392, 0.0000, 3.6682], device='cuda:0')
# epoch 28, rescalings_1 :  tensor([0.4514, 0.3385, 4.2133], device='cuda:0')
# epoch 28, rescalings_2 :  tensor([0.9329, 0.3654, 4.7976], device='cuda:0')
# Loss [29, 100](epoch, minibatch):  0.15173341140151023
# Loss [29, 200](epoch, minibatch):  0.1502395363152027
# Loss [29, 300](epoch, minibatch):  0.1586364582180977
# epoch 28, dts_0 :  tensor([0.1440, 0.3067, 0.1827, 0.4012], device='cuda:0')
# epoch 28, dts_1 :  tensor([0.1430, 0.3044, 0.1434, 0.3052], device='cuda:0')
# epoch 28, dts_2 :  tensor([0.1413, 0.3003, 0.1413, 0.3003], device='cuda:0')
# Norms: [0.9960050582885742, 0.9921621084213257, 1.0000615119934082, 1.0029300451278687, 1.0002992153167725, 1.033613681793213, 1.0004018545150757, 1.0192617177963257, 0.9997793436050415, 1.0072509050369263, 1.0000274181365967, 0.9992642402648926]
# Orthogonality violation: [0.0031112844590097666, 0.015591691248118877, 0.0038373880088329315, 0.02601499669253826, 0.005077870562672615, 0.026651723310351372, 0.005311505403369665, 0.021705416962504387, 0.003946433309465647, 0.019584419205784798, 0.0020259597804397345, 0.015672720968723297]
# Reg term: 0.14853140711784363
# Norms lifting layers: [0.9969412684440613, 0.9895502328872681, 0.9902323484420776]
# Lifting orth viol: [1.4809819459915161, 5.418369293212891, 7.821659564971924]
# Norm last linear: 1.0
# Current accuracy on test points: 64 %
# epoch 29, rescalings_0 :  tensor([2.8617e-02, 1.1847e-05, 3.7057e+00], device='cuda:0')
# epoch 29, rescalings_1 :  tensor([0.4576, 0.3429, 4.2551], device='cuda:0')
# epoch 29, rescalings_2 :  tensor([0.9416, 0.3709, 4.8432], device='cuda:0')
# Loss [30, 100](epoch, minibatch):  0.15214908994734289
# Loss [30, 200](epoch, minibatch):  0.15621670745313168
# Loss [30, 300](epoch, minibatch):  0.15559826083481312
# epoch 29, dts_0 :  tensor([0.1504, 0.3218, 0.1880, 0.4152], device='cuda:0')
# epoch 29, dts_1 :  tensor([0.1416, 0.3010, 0.1418, 0.3016], device='cuda:0')
# epoch 29, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9956254959106445, 0.9993860125541687, 0.9999094605445862, 0.9972555637359619, 0.9984449148178101, 1.0007283687591553, 1.0000089406967163, 1.0002501010894775, 1.000547170639038, 0.9978711605072021, 1.0000478029251099, 0.9947994947433472]
# Orthogonality violation: [0.003421026049181819, 0.014460688456892967, 0.0028461406473070383, 0.02298819087445736, 0.003141578286886215, 0.015405974350869656, 0.0030513776000589132, 0.013699001632630825, 0.005179005675017834, 0.016307516023516655, 0.002205359051004052, 0.013585401698946953]
# Reg term: 0.11629125475883484
# Norms lifting layers: [0.9975830912590027, 0.9989211559295654, 0.9939340949058533]
# Lifting orth viol: [1.4675194025039673, 5.420153617858887, 7.826767444610596]
# Norm last linear: 1.0
# Current accuracy on test points: 65 %
# epoch 30, rescalings_0 :  tensor([1.8953e-02, 2.7292e-06, 3.7385e+00], device='cuda:0')
# epoch 30, rescalings_1 :  tensor([0.4673, 0.3488, 4.2940], device='cuda:0')
# epoch 30, rescalings_2 :  tensor([0.9516, 0.3752, 4.8868], device='cuda:0')
# Loss [31, 100](epoch, minibatch):  0.11538786463439464
# Loss [31, 200](epoch, minibatch):  0.10062697261571885
# Loss [31, 300](epoch, minibatch):  0.09821439851075411
# epoch 30, dts_0 :  tensor([0.1426, 0.3033, 0.1809, 0.3967], device='cuda:0')
# epoch 30, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 30, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9997245669364929, 0.99897301197052, 1.0000019073486328, 0.9977150559425354, 0.9997246265411377, 0.9968830347061157, 1.00002121925354, 0.9969136714935303, 0.999301552772522, 0.9938851594924927, 0.9999713897705078, 0.9937022924423218]
# Orthogonality violation: [0.00019951816648244858, 0.001640008995309472, 8.019565575523302e-05, 0.0029887203127145767, 0.00032489519799128175, 0.00241529056802392, 0.00036124090547673404, 0.0022839985322207212, 0.0004987951251678169, 0.0016605453565716743, 0.00019463167700450867, 0.0013146661221981049]
# Reg term: 0.013962505385279655
# Norms lifting layers: [0.9996289610862732, 0.9805065393447876, 0.9998632073402405]
# Lifting orth viol: [1.4702744483947754, 5.408410549163818, 7.821867942810059]
# Norm last linear: 1.0
# Current accuracy on test points: 74 %
# epoch 31, rescalings_0 :  tensor([1.8471e-02, 6.8589e-07, 3.7475e+00], device='cuda:0')
# epoch 31, rescalings_1 :  tensor([0.4674, 0.3491, 4.3028], device='cuda:0')
# epoch 31, rescalings_2 :  tensor([0.9527, 0.3757, 4.8964], device='cuda:0')
# Loss [32, 100](epoch, minibatch):  0.09205235291272401
# Loss [32, 200](epoch, minibatch):  0.09252817511558532
# Loss [32, 300](epoch, minibatch):  0.08866824276745319
# epoch 31, dts_0 :  tensor([0.1412, 0.3000, 0.1769, 0.3865], device='cuda:0')
# epoch 31, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 31, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.999695897102356, 0.9994584918022156, 1.0000128746032715, 1.0002775192260742, 0.999727725982666, 0.9968581199645996, 0.9999867677688599, 0.9969288110733032, 0.9992951154708862, 0.9936579465866089, 0.9999665021896362, 0.9934831261634827]
# Orthogonality violation: [0.00022123093367554247, 0.001311036292463541, 0.00046337154344655573, 0.002462107688188553, 0.0002572497760411352, 0.0023384925443679094, 0.00027880704146809876, 0.001954215345904231, 0.00042400581878609955, 0.0016172990435734391, 0.00016027080710045993, 0.0013148646103218198]
# Reg term: 0.012802951969206333
# Norms lifting layers: [0.9995932579040527, 0.9996886253356934, 0.993155837059021]
# Lifting orth viol: [1.4691779613494873, 5.40424108505249, 7.816641330718994]
# Norm last linear: 1.0
# Current accuracy on test points: 75 %
# epoch 32, rescalings_0 :  tensor([0.0180, 0.0000, 3.7563], device='cuda:0')
# epoch 32, rescalings_1 :  tensor([0.4673, 0.3494, 4.3128], device='cuda:0')
# epoch 32, rescalings_2 :  tensor([0.9540, 0.3763, 4.9073], device='cuda:0')
# Loss [33, 100](epoch, minibatch):  0.08442505490034818
# Loss [33, 200](epoch, minibatch):  0.08597979221493006
# Loss [33, 300](epoch, minibatch):  0.08349400624632836
# epoch 32, dts_0 :  tensor([0.1412, 0.3000, 0.1738, 0.3788], device='cuda:0')
# epoch 32, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 32, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0001835823059082, 0.9995191097259521, 1.0, 0.9977508187294006, 0.999721348285675, 0.9974514842033386, 0.9999771118164062, 0.9973676204681396, 0.9993087649345398, 0.9941112995147705, 0.9999644160270691, 0.9934823513031006]
# Orthogonality violation: [0.00019887957023456693, 0.0013653637142851949, 0.00021847571770194918, 0.0020837069023400545, 0.0002131671499228105, 0.0019882312044501305, 0.00022163023822940886, 0.001897242502309382, 0.0003709287557285279, 0.0013923327205702662, 0.00013911828864365816, 0.0010746370535343885]
# Reg term: 0.011163713410496712
# Norms lifting layers: [0.9997835159301758, 0.9994456768035889, 0.9960364103317261]
# Lifting orth viol: [1.4666706323623657, 5.405353546142578, 7.812237739562988]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 76 %
# epoch 33, rescalings_0 :  tensor([0.0178, 0.0000, 3.7649], device='cuda:0')
# epoch 33, rescalings_1 :  tensor([0.4673, 0.3495, 4.3229], device='cuda:0')
# epoch 33, rescalings_2 :  tensor([0.9551, 0.3768, 4.9180], device='cuda:0')
# Loss [34, 100](epoch, minibatch):  0.08287696331739426
# Loss [34, 200](epoch, minibatch):  0.0817757898196578
# Loss [34, 300](epoch, minibatch):  0.0814630663394928
# epoch 33, dts_0 :  tensor([0.1412, 0.3000, 0.1695, 0.3680], device='cuda:0')
# epoch 33, dts_1 :  tensor([0.1412, 0.3001, 0.1412, 0.3001], device='cuda:0')
# epoch 33, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [1.0002045631408691, 0.9977585077285767, 0.9999935626983643, 0.9989742040634155, 0.999714195728302, 0.9973634481430054, 0.9999666810035706, 0.9977384805679321, 0.9993034601211548, 0.9935873746871948, 0.999965250492096, 0.9932857751846313]
# ...
# Lifting orth viol: [1.415865421295166, 5.452120780944824, 7.77817440032959]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 78 %
# epoch 89, rescalings_0 :  tensor([0.5060, 1.0000, 4.9734], device='cuda:0')
# epoch 89, rescalings_1 :  tensor([1.0000e+00, 6.5734e-06, 5.8772e+00], device='cuda:0')
# epoch 89, rescalings_2 :  tensor([1.0000, 1.0000, 6.9672], device='cuda:0')
# Loss [90, 100](epoch, minibatch):  0.2935571452975273
# Loss [90, 200](epoch, minibatch):  0.3046578800678253
# Loss [90, 300](epoch, minibatch):  0.3023505188524723
# epoch 89, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 89, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 89, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985702633857727, 1.0004839897155762, 0.9991335868835449, 0.999971866607666, 0.9988207817077637, 0.9982901215553284, 1.000000238418579, 0.9982814788818359, 0.9969947934150696, 0.9965667724609375, 0.9963386058807373, 0.9964556694030762]
# Orthogonality violation: [7.586900755995885e-05, 0.002646415028721094, 0.0005146001349203289, 0.002295535523444414, 0.0006508370861411095, 0.0033601215109229088, 2.67487430392066e-05, 0.0035176039673388004, 0.0006512539694085717, 0.0028078772593289614, 0.0005616184789687395, 0.0023412371519953012]
# Reg term: 0.019449718296527863
# Norms lifting layers: [0.9999778270721436, 1.0000269412994385, 0.9998502135276794]
# Lifting orth viol: [1.41433846950531, 5.45329475402832, 7.779210567474365]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 78 %
# epoch 90, rescalings_0 :  tensor([0.5062, 1.0000, 4.9786], device='cuda:0')
# epoch 90, rescalings_1 :  tensor([9.9999e-01, 3.4613e-06, 5.8823e+00], device='cuda:0')
# epoch 90, rescalings_2 :  tensor([1.0000, 1.0000, 6.9719], device='cuda:0')
# Loss [91, 100](epoch, minibatch):  0.30494180947542193
# Loss [91, 200](epoch, minibatch):  0.2888152177631855
# Loss [91, 300](epoch, minibatch):  0.28576947703957556
# epoch 90, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 90, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 90, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.998586893081665, 0.9991405606269836, 0.9991415739059448, 0.999144971370697, 0.9988134503364563, 0.9990665912628174, 1.0000009536743164, 0.9988876581192017, 0.9969953298568726, 0.9967036247253418, 0.9963279962539673, 0.9965709447860718]
# Orthogonality violation: [6.612443394260481e-05, 0.0020789634436368942, 0.0004848490934818983, 0.0019053432624787092, 0.0006132404087111354, 0.0028458291199058294, 3.5485891203279607e-06, 0.0031837692949920893, 0.0006242599338293076, 0.002459751209244132, 0.0005440770764835179, 0.0020860752556473017]
# Reg term: 0.016895830631256104
# Norms lifting layers: [0.9999762177467346, 0.9998542070388794, 0.999992311000824]
# Lifting orth viol: [1.4144920110702515, 5.4535231590271, 7.778776168823242]
# Norm last linear: 1.0
# Current accuracy on test points: 79 %
# epoch 91, rescalings_0 :  tensor([0.5063, 1.0000, 4.9792], device='cuda:0')
# epoch 91, rescalings_1 :  tensor([1.0000e+00, 1.8270e-06, 5.8828e+00], device='cuda:0')
# epoch 91, rescalings_2 :  tensor([1.0000, 1.0000, 6.9724], device='cuda:0')
# Loss [92, 100](epoch, minibatch):  0.29515357196331027
# Loss [92, 200](epoch, minibatch):  0.2885241003334522
# Loss [92, 300](epoch, minibatch):  0.2849613818526268
# epoch 91, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 91, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 91, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985857009887695, 0.9989347457885742, 0.9991117715835571, 0.9990213513374329, 0.9988189935684204, 0.9992970824241638, 1.0000008344650269, 0.9990228414535522, 0.9969982504844666, 0.9965795278549194, 0.9963397979736328, 0.9964695572853088]
# Orthogonality violation: [6.584796938113868e-05, 0.0021000944543629885, 0.0004840670444536954, 0.0019111718283966184, 0.0006118715391494334, 0.0028657177463173866, 3.5921013932238566e-06, 0.003188947681337595, 0.0006241534138098359, 0.0024597023148089647, 0.0005438858643174171, 0.002087380737066269]
# Reg term: 0.01694643311202526
# Norms lifting layers: [0.9999083876609802, 0.9999963045120239, 0.9999692440032959]
# Lifting orth viol: [1.4143236875534058, 5.4533843994140625, 7.778525352478027]
# Norm last linear: 1.0000001192092896
# Current accuracy on test points: 79 %
# epoch 92, rescalings_0 :  tensor([0.5063, 1.0000, 4.9797], device='cuda:0')
# epoch 92, rescalings_1 :  tensor([1.0000e+00, 8.2229e-06, 5.8834e+00], device='cuda:0')
# epoch 92, rescalings_2 :  tensor([1.0000, 1.0000, 6.9729], device='cuda:0')
# Loss [93, 100](epoch, minibatch):  0.29064871206879617
# Loss [93, 200](epoch, minibatch):  0.2855634818971157
# Loss [93, 300](epoch, minibatch):  0.2798353172838688
# epoch 92, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 92, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 92, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.99858558177948, 0.9987992644309998, 0.9991111755371094, 0.9988762736320496, 0.998788058757782, 0.9992101788520813, 1.0000009536743164, 0.9990054368972778, 0.9969969391822815, 0.9967725276947021, 0.996326208114624, 0.9966453909873962]
# Orthogonality violation: [6.560055044246837e-05, 0.0020919805392622948, 0.0004863509093411267, 0.0019246733281761408, 0.0006117623415775597, 0.0028413773979991674, 3.6351880225993227e-06, 0.00317932665348053, 0.0006237479974515736, 0.0024517334531992674, 0.0005436913343146443, 0.002081539947539568]
# Reg term: 0.016905419528484344
# Norms lifting layers: [0.999977707862854, 1.0000026226043701, 0.9999754428863525]
# Lifting orth viol: [1.4142754077911377, 5.453536033630371, 7.778292655944824]
# Norm last linear: 1.0000001192092896
# Current accuracy on test points: 79 %
# epoch 93, rescalings_0 :  tensor([0.5063, 1.0000, 4.9803], device='cuda:0')
# epoch 93, rescalings_1 :  tensor([1.0000e+00, 2.7071e-08, 5.8839e+00], device='cuda:0')
# epoch 93, rescalings_2 :  tensor([1.0000, 1.0000, 6.9734], device='cuda:0')
# Loss [94, 100](epoch, minibatch):  0.2879307396709919
# Loss [94, 200](epoch, minibatch):  0.29117839261889455
# Loss [94, 300](epoch, minibatch):  0.2781680120527744
# epoch 93, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 93, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 93, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985888600349426, 0.9994622468948364, 0.9991475343704224, 0.9993881583213806, 0.998832106590271, 0.9987717270851135, 1.0000007152557373, 0.9986940622329712, 0.9969884157180786, 0.9965915083885193, 0.996326744556427, 0.9964712262153625]
# Orthogonality violation: [6.555512663908303e-05, 0.0020686436910182238, 0.00048357812920585275, 0.0019008687231689692, 0.0006119887111708522, 0.002837223932147026, 3.72352610611415e-06, 0.0031737391836941242, 0.0006231772131286561, 0.0024612490087747574, 0.0005432871403172612, 0.002086860593408346]
# Reg term: 0.01685989648103714
# Norms lifting layers: [0.9999950528144836, 0.9999923706054688, 0.9999970197677612]
# Lifting orth viol: [1.4144169092178345, 5.453723907470703, 7.777982234954834]
# Norm last linear: 1.0000001192092896
# Current accuracy on test points: 79 %
# epoch 94, rescalings_0 :  tensor([0.5063, 1.0000, 4.9809], device='cuda:0')
# epoch 94, rescalings_1 :  tensor([1.0000, 0.0000, 5.8844], device='cuda:0')
# epoch 94, rescalings_2 :  tensor([1.0000, 1.0000, 6.9739], device='cuda:0')
# Loss [95, 100](epoch, minibatch):  0.28907514438033105
# Loss [95, 200](epoch, minibatch):  0.27477786764502526
# Loss [95, 300](epoch, minibatch):  0.29005667701363563
# epoch 94, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 94, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 94, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985854625701904, 0.998999297618866, 0.9991216063499451, 0.9990993142127991, 0.9988206624984741, 0.9990524649620056, 1.0000009536743164, 0.9988804459571838, 0.9969973564147949, 0.9966500997543335, 0.9963344931602478, 0.9965349435806274]
# Orthogonality violation: [6.587946700165048e-05, 0.0020690876990556717, 0.00048224785132333636, 0.0018911914667114615, 0.0006103236810304224, 0.0028260659892112017, 3.7842178244318347e-06, 0.0031690094619989395, 0.0006224137032404542, 0.0024439042899757624, 0.0005428758449852467, 0.002074864227324724]
# Reg term: 0.01680164784193039
# Norms lifting layers: [0.9999807476997375, 0.9999710321426392, 0.9999675750732422]
# Lifting orth viol: [1.414516806602478, 5.453831672668457, 7.777817726135254]
# Norm last linear: 1.0
# Current accuracy on test points: 79 %
# epoch 95, rescalings_0 :  tensor([0.5063, 1.0000, 4.9815], device='cuda:0')
# epoch 95, rescalings_1 :  tensor([1.0000e+00, 2.5648e-07, 5.8850e+00], device='cuda:0')
# epoch 95, rescalings_2 :  tensor([1.0000, 1.0000, 6.9744], device='cuda:0')
# Loss [96, 100](epoch, minibatch):  0.28705616608262063
# Loss [96, 200](epoch, minibatch):  0.286594811975956
# Loss [96, 300](epoch, minibatch):  0.2842899590730667
# epoch 95, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 95, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 95, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985896348953247, 0.9988723397254944, 0.999121904373169, 0.9990304708480835, 0.9988299608230591, 0.9990599155426025, 1.0000007152557373, 0.9989186525344849, 0.9969946146011353, 0.9967004060745239, 0.99632328748703, 0.9965754151344299]
# Orthogonality violation: [6.538943125633523e-05, 0.0020428840070962906, 0.00048257174785248935, 0.001883016200736165, 0.0006108732777647674, 0.0028173935133963823, 3.4949698601849377e-06, 0.003164829919114709, 0.0006225213874131441, 0.002441050950437784, 0.0005428253789432347, 0.0020714045967906713]
# Reg term: 0.016748255118727684
# Norms lifting layers: [0.9999851584434509, 0.9999945759773254, 0.9999924898147583]
# Lifting orth viol: [1.4146283864974976, 5.453943729400635, 7.777618885040283]
# Norm last linear: 1.0
# Current accuracy on test points: 79 %
# epoch 96, rescalings_0 :  tensor([0.5064, 1.0000, 4.9820], device='cuda:0')
# epoch 96, rescalings_1 :  tensor([1.0000, 0.0000, 5.8855], device='cuda:0')
# epoch 96, rescalings_2 :  tensor([1.0000, 1.0000, 6.9749], device='cuda:0')
# Loss [97, 100](epoch, minibatch):  0.2885731561481953
# Loss [97, 200](epoch, minibatch):  0.2877332228422165
# Loss [97, 300](epoch, minibatch):  0.27956289052963257
# epoch 96, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 96, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 96, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.998587965965271, 0.9992774128913879, 0.9991179704666138, 0.9992502331733704, 0.9988081455230713, 0.9986788630485535, 1.0000009536743164, 0.9985974431037903, 0.9969855546951294, 0.9966617822647095, 0.9963205456733704, 0.9965417981147766]
# Orthogonality violation: [6.535115244332701e-05, 0.002036234363913536, 0.00048176394193433225, 0.0018789934692904353, 0.0006102190236561, 0.002818267559632659, 3.7083007100591203e-06, 0.003164492081850767, 0.0006221546209417284, 0.0024488719645887613, 0.0005426754942163825, 0.002077065408229828]
# Reg term: 0.016749797388911247
# Norms lifting layers: [0.9999929070472717, 0.9999805688858032, 0.9999902248382568]
# Lifting orth viol: [1.4145581722259521, 5.454082489013672, 7.7774977684021]
# Norm last linear: 1.0
# Current accuracy on test points: 79 %
# epoch 97, rescalings_0 :  tensor([0.5064, 1.0000, 4.9826], device='cuda:0')
# epoch 97, rescalings_1 :  tensor([1.0000e+00, 4.7020e-06, 5.8861e+00], device='cuda:0')
# epoch 97, rescalings_2 :  tensor([1.0000, 1.0000, 6.9754], device='cuda:0')
# Loss [98, 100](epoch, minibatch):  0.2830152279138565
# Loss [98, 200](epoch, minibatch):  0.28540502816438673
# Loss [98, 300](epoch, minibatch):  0.28110314428806304
# epoch 97, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 97, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 97, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985865354537964, 0.9989643096923828, 0.9991058111190796, 0.9990322589874268, 0.998801589012146, 0.9990232586860657, 1.0000009536743164, 0.9988498091697693, 0.9969956278800964, 0.9966956377029419, 0.9963282346725464, 0.9965587258338928]
# Orthogonality violation: [6.536518048960716e-05, 0.0020291367545723915, 0.00048256738227792084, 0.0018807444721460342, 0.0006092836265452206, 0.002800388028845191, 3.6366745916893706e-06, 0.003153258003294468, 0.0006217558402568102, 0.0024400220718234777, 0.0005421568639576435, 0.002070354763418436]
# Reg term: 0.016698669642210007
# Norms lifting layers: [0.9999983310699463, 0.9999885559082031, 0.9999140501022339]
# Lifting orth viol: [1.4146190881729126, 5.454147815704346, 7.777246952056885]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 79 %
# epoch 98, rescalings_0 :  tensor([0.5064, 1.0000, 4.9832], device='cuda:0')
# epoch 98, rescalings_1 :  tensor([1.0000e+00, 1.3530e-06, 5.8866e+00], device='cuda:0')
# epoch 98, rescalings_2 :  tensor([1.0000, 1.0000, 6.9758], device='cuda:0')
# Loss [99, 100](epoch, minibatch):  0.28148100033402446
# Loss [99, 200](epoch, minibatch):  0.2877407619357109
# Loss [99, 300](epoch, minibatch):  0.28805140882730484
# epoch 98, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 98, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 98, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985818266868591, 0.9992705583572388, 0.9991311430931091, 0.9992219805717468, 0.9987955093383789, 0.9988518357276917, 1.0000007152557373, 0.9987444877624512, 0.9969837665557861, 0.9967119693756104, 0.9963209629058838, 0.9965882301330566]
# Orthogonality violation: [6.522543117171153e-05, 0.002037695376202464, 0.00048115040408447385, 0.0018777261720970273, 0.0006088794907554984, 0.0028256329242140055, 3.632958168964251e-06, 0.003165425267070532, 0.0006213029264472425, 0.0024447645992040634, 0.0005419725785031915, 0.002072572475299239]
# Reg term: 0.016745980829000473
# Norms lifting layers: [0.9999938011169434, 0.99998539686203, 0.999987781047821]
# Lifting orth viol: [1.4146804809570312, 5.454415321350098, 7.776950836181641]
# Norm last linear: 1.0
# Current accuracy on test points: 79 %
# epoch 99, rescalings_0 :  tensor([0.5064, 1.0000, 4.9837], device='cuda:0')
# epoch 99, rescalings_1 :  tensor([9.9999e-01, 4.0914e-06, 5.8871e+00], device='cuda:0')
# epoch 99, rescalings_2 :  tensor([1.0000, 1.0000, 6.9763], device='cuda:0')
# Loss [100, 100](epoch, minibatch):  0.2882644720375538
# Loss [100, 200](epoch, minibatch):  0.28679140359163285
# Loss [100, 300](epoch, minibatch):  0.2839349703490734
# epoch 99, dts_0 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 99, dts_1 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# epoch 99, dts_2 :  tensor([0.1412, 0.3000, 0.1412, 0.3000], device='cuda:0')
# Norms: [0.9985904693603516, 0.9990289211273193, 0.9991151094436646, 0.9990864396095276, 0.9988408088684082, 0.9986876249313354, 1.0000007152557373, 0.9986339807510376, 0.9969996213912964, 0.9966463446617126, 0.9963398575782776, 0.9965424537658691]
# Orthogonality violation: [6.554109859280288e-05, 0.0020474689081311226, 0.00048157834680750966, 0.0018785996362566948, 0.0006108658853918314, 0.0028494568541646004, 4.045454261358827e-06, 0.003171309595927596, 0.0006216204492375255, 0.0024505960755050182, 0.0005421483074314892, 0.0020780968479812145]
# Reg term: 0.01680132746696472
# Norms lifting layers: [0.9999960660934448, 0.9999904632568359, 0.9999904632568359]
# Lifting orth viol: [1.414624571800232, 5.454463005065918, 7.777083873748779]
# Norm last linear: 0.9999999403953552
# Current accuracy on test points: 79 %
# Training Done
